# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scrublet as scr

# %matplotlib inline

# %%
sc.settings.verbosity = 3           
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.7.2 anndata==0.7.5 umap==0.5.1 numpy==1.19.5 scipy==1.6.2 pandas==1.1.5 scikit-learn==0.24.1 statsmodels==0.12.2 python-igraph==0.8.3 louvain==0.7.0 leidenalg==0.8.3

# %%
results_file = 'write/GSE142585_Hum.h5ad'

# %%
adata = sc.read_text('GSE142585_MergedHumanTestis4_DGE.txt')

# %%
adata = adata.T

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 13837 × 46541

# %%
sc.pl.highest_expr_genes(adata, n_top=20)
# Out:
# normalizing counts per cell
#     finished (0:00:07)

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')

# %%
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 13837 × 46541
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts'], jitter=0.4, rotation= 45)
sc.pl.violin(adata, ['pct_counts_mt'], jitter=0.4, rotation= 45)

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
adata = adata[adata.obs['pct_counts_mt'] < 10, :]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 13837 × 46541
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# Trying to set attribute `.obs` of view, copying.
# filtered out 6683 genes that are detected in less than 3 cells

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 13837 × 39858
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells'

# %%
sc.pl.violin(adata, ['pct_counts_mt'], jitter=0.4, rotation= 45)
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')

# %%
adata.raw = adata

# %%
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)
sc.pp.scale(adata)
# Out:
# normalizing by total count per cell
#     finished (0:00:02): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)

# %%
scrub = scr.Scrublet(adata.raw.X)
adata.obs['doublet_scores'], adata.obs['predicted_doublets'] = scrub.scrub_doublets()
scrub.plot_histogram()

sum(adata.obs['predicted_doublets'])
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.40
# Detected doublet rate = 1.5%
# Estimated detectable doublet fraction = 48.8%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 3.1%
# Elapsed time: 14.6 seconds
# 209

# %%
adata.obs['doublet_info'] = adata.obs["predicted_doublets"].astype(str)

# %%
sc.pl.violin(adata, 'n_genes_by_counts',
             jitter=0.4, groupby = 'doublet_info', rotation=45)
# Out:
# ... storing 'doublet_info' as categorical

# %%
adata = adata.raw.to_adata() 

adata = adata[adata.obs['doublet_info'] == 'False',:]
print(adata.shape)
# Out:
# (13628, 39858)

# %%
adata.write(results_file)
