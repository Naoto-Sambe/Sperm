# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scrublet as scr

# %matplotlib inline

# %%
sc.settings.verbosity = 3           
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.7.2 anndata==0.7.5 umap==0.5.1 numpy==1.19.5 scipy==1.6.2 pandas==1.1.5 scikit-learn==0.24.1 statsmodels==0.12.2 python-igraph==0.8.3 louvain==0.7.0 leidenalg==0.8.3

# %%
results_file = 'write/230212_Hum_QC_R1.h5ad'

# %%
adata = sc.read_10x_mtx(
    '/mnt/d/Sambe/GSM3526588/',  
    cache=True)
# Out:
# ... reading from cache file cache/mnt-d-Sambe-GSM3526588-matrix.h5ad

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4955 × 32738
#     var: 'gene_ids', 'feature_types'

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACCTGAGCGATTCT-1, AAACCTGAGCGTTTAC-1, AAACCTGAGGACAGAA-1, AAACCTGAGTCCATAC-1, AAACCTGCAACACGCC-1, AAACCTGCAAGTTAAG-1, AAACCTGCACCAGCAC-1, AAACCTGGTCGACTAT-1, AAACCTGTCATGTGGT-1, AAACCTGTCCATGAGT-1, AAACCTGTCGAACTGT-1, AAACCTGTCGCGTAGC-1, AAACCTGTCGGAATCT-1, AAACCTGTCGTCTGAA-1, AAACCTGTCTCGCTTG-1, AAACGGGAGACGCAAC-1, AAACGGGAGACGCTTT-1, AAACGGGAGATGGGTC-1, AAACGGGAGATGTTAG-1, AAACGGGCAATGGATA-1, AAACGGGCACTGTGTA-1, AAACGGGGTACCGCTG-1, AAACGGGGTATTAGCC-1, AAACGGGGTCCAGTGC-1, AAAGATGAGGCGTACA-1, AAAGATGAGGGATGGG-1, AAAGATGCATGCCCGA-1, AAAGATGCATGTCCTC-1, AAAGATGCATTGGGCC-1, AAAGATGGTAGCGTGA-1, AAAGATGGTCACAAGG-1, AAAGATGGTCTTCTCG-1, AAAGATGGTGTTGGGA-1, AAAGATGGTTAAAGTG-1, AAAGATGTCACTGGGC-1, AAAGATGTCCAGGGCT-1, AAAGATGTCGTGGGAA-1, AAAGCAAAGGGATACC-1, AAAGCAACACTGTTAG-1, AAAGCAACAGGACCCT-1, AAAGCAAGTGTGTGCC-1, AAAGCAATCCAGAAGG-1, AAAGCAATCCTCATTA-1, AAAGCAATCCTCGCAT-1, AAAGTAGAGGAATGGA-1, AAAGTAGAGGCAAAGA-1, AAAGTAGAGTTACGGG-1, AAAGTAGCAAAGTGCG-1, AAAGTAGCAGCTTCGG-1, AAAGTAGCATTAACCG-1, AAAGTAGGTATGCTTG-1, AAAGTAGTCAAACAAG-1, AAAGTAGTCCACTCCA-1, AAAGTAGTCGAATCCA-1, AAAGTAGTCGCAAGCC-1, AAAGTAGTCTTCATGT-1, AAATGCCAGACGCAAC-1, AAATGCCAGCGTCTAT-1, AAATGCCAGGTGCAAC-1, AAATGCCAGTGTTAGA-1, AAATGCCCAAAGGCGT-1, AAATGCCGTAATAGCA-1, AAATGCCGTGCATCTA-1, AAATGCCGTTAAGAAC-1, AACACGTAGATAGCAT-1, AACACGTAGTAGCGGT-1, AACACGTCAGATGGGT-1, AACACGTCATACGCTA-1, AACACGTCATCCCATC-1, AACACGTGTAATAGCA-1, AACACGTGTCGCTTTC-1, AACACGTGTGTAATGA-1, AACACGTTCTCAAGTG-1, AACACGTTCTTGTACT-1, AACCATGAGAGCCTAG-1, AACCATGAGCCACGTC-1, AACCATGAGTGAACAT-1, AACCATGCAAGAGGCT-1, AACCATGCAAGTCTAC-1, AACCATGCATTGAGCT-1, AACCATGGTAAAGTCA-1, AACCATGGTAGCAAAT-1, AACCATGGTCATCCCT-1, AACCATGGTTAAGATG-1, AACCATGGTTGCTCCT-1, AACCATGTCAGAAATG-1, AACCATGTCTAACTGG-1, AACCATGTCTATCCTA-1, AACCGCGAGAAGGGTA-1, AACCGCGAGAGTACAT-1, AACCGCGAGGCAGTCA-1, AACCGCGAGTATCGAA-1, AACCGCGCAAAGAATC-1, AACCGCGCACGAAACG-1, AACCGCGGTAGGACAC-1, AACCGCGGTTCACCTC-1, AACCGCGGTTGTACAC-1, AACCGCGTCCACGACG-1, AACGTTGAGAACTGTA-1, AACGTTGAGTGGTAGC-1, ...]
#
# [4955 rows x 0 columns]

# %%
adata.var
# Out:
#                      gene_ids    feature_types
# MIR1302-10    ENSG00000243485  Gene Expression
# FAM138A       ENSG00000237613  Gene Expression
# OR4F5         ENSG00000186092  Gene Expression
# RP11-34P13.7  ENSG00000238009  Gene Expression
# RP11-34P13.8  ENSG00000239945  Gene Expression
# ...                       ...              ...
# AC145205.1    ENSG00000215635  Gene Expression
# BAGE5         ENSG00000268590  Gene Expression
# CU459201.1    ENSG00000251180  Gene Expression
# AC002321.2    ENSG00000215616  Gene Expression
# AC002321.1    ENSG00000215611  Gene Expression
#
# [32738 rows x 2 columns]

# %%
sc.pl.highest_expr_genes(adata, n_top=20)
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')

# %%
adata.var
# Out:
#                      gene_ids    feature_types     mt
# MIR1302-10    ENSG00000243485  Gene Expression  False
# FAM138A       ENSG00000237613  Gene Expression  False
# OR4F5         ENSG00000186092  Gene Expression  False
# RP11-34P13.7  ENSG00000238009  Gene Expression  False
# RP11-34P13.8  ENSG00000239945  Gene Expression  False
# ...                       ...              ...    ...
# AC145205.1    ENSG00000215635  Gene Expression  False
# BAGE5         ENSG00000268590  Gene Expression  False
# CU459201.1    ENSG00000251180  Gene Expression  False
# AC002321.2    ENSG00000215616  Gene Expression  False
# AC002321.1    ENSG00000215611  Gene Expression  False
#
# [32738 rows x 3 columns]

# %%
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4955 × 32738
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts'], jitter=0.4, rotation= 45)
sc.pl.violin(adata, ['pct_counts_mt'], jitter=0.4, rotation= 45)
# Out:
# ... storing 'feature_types' as categorical

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
adata.obs
# Out:
#                     n_genes_by_counts  total_counts  total_counts_mt  \
# AAACCTGAGCGATTCT-1               2112        5928.0            101.0
# AAACCTGAGCGTTTAC-1               3743        8950.0            403.0
# AAACCTGAGGACAGAA-1               1588        4337.0            112.0
# AAACCTGAGTCCATAC-1               2783        5283.0            391.0
# AAACCTGCAACACGCC-1               4327       11135.0            708.0
# ...                               ...           ...              ...
# TTTGTCACATCACCCT-1               1592        2644.0            496.0
# TTTGTCAGTAGCTGCC-1               2225        4007.0            256.0
# TTTGTCATCTAAGCCA-1               1627        3926.0             97.0
# TTTGTCATCTACTATC-1               1475        2420.0            363.0
# TTTGTCATCTGAGTGT-1               2058        5568.0             93.0
#
#                     pct_counts_mt
# AAACCTGAGCGATTCT-1       1.703779
# AAACCTGAGCGTTTAC-1       4.502793
# AAACCTGAGGACAGAA-1       2.582430
# AAACCTGAGTCCATAC-1       7.401098
# AAACCTGCAACACGCC-1       6.358330
# ...                           ...
# TTTGTCACATCACCCT-1      18.759455
# TTTGTCAGTAGCTGCC-1       6.388819
# TTTGTCATCTAAGCCA-1       2.470708
# TTTGTCATCTACTATC-1      15.000001
# TTTGTCATCTGAGTGT-1       1.670259
#
# [4955 rows x 4 columns]

# %%
adata = adata[adata.obs['pct_counts_mt'] < 10, :]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 4762 × 32738
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
# Out:
# Trying to set attribute `.obs` of view, copying.
# filtered out 9208 genes that are detected in less than 3 cells

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4762 × 23530
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells'

# %%
sc.pl.violin(adata, ['pct_counts_mt'], jitter=0.4, rotation= 45)
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')

# %%
adata.raw = adata

# %%
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)
sc.pp.scale(adata)
# Out:
# normalizing by total count per cell
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption

# %%
scrub = scr.Scrublet(adata.raw.X)
adata.obs['doublet_scores'], adata.obs['predicted_doublets'] = scrub.scrub_doublets()
scrub.plot_histogram()

sum(adata.obs['predicted_doublets'])
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.26
# Detected doublet rate = 4.2%
# Estimated detectable doublet fraction = 66.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 6.4%
# Elapsed time: 4.0 seconds
# 201

# %%
adata.obs['doublet_info'] = adata.obs["predicted_doublets"].astype(str)

# %%
sc.pl.violin(adata, 'n_genes_by_counts',
             jitter=0.4, groupby = 'doublet_info', rotation=45)
# Out:
# ... storing 'doublet_info' as categorical

# %%
adata = adata.raw.to_adata() 

adata = adata[adata.obs['doublet_info'] == 'False',:]
print(adata.shape)
# Out:
# (4561, 23530)

# %%
adata.write(results_file)
